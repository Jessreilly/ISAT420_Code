# %%
import pandas as pd

aqs_Glendora2009 = pd.read_csv('../data/2009_EPA_AQI_Glendora.csv',
                parse_dates = ['Date'],
                index_col = ['Date']
                  )
aqs_Glendora2009

aqs_Compton2009 = pd.read_csv('../data/2009_EPA_AQI_Compton.csv',
                parse_dates = ['Date'],
                index_col = ['Date']
                  )
aqs_Compton2009

aqs_FULL2009 = pd.read_csv('../data/2009_EPA_AQI_FULL.csv',
                parse_dates = ['Date'],
                index_col = ['Date']
                  )
aqs_FULL2009

aqs_FULL2009_ComparisonData = pd.read_csv('../data/2009_EPA_AQI_ComparisonData.csv',
                parse_dates = ['Date'],
                index_col = ['Date']
                  )
aqs_FULL2009_ComparisonData

aqs_FULL2010 = pd.read_csv('../data/2010_EPA_AQI_FULL.csv',
                parse_dates = ['Date'],
                index_col = ['Date']
                  )
aqs_FULL2010

aqs_FULL2011 = pd.read_csv('../data/2011_EPA_AQI_FULL.csv',
                parse_dates = ['Date'],
                index_col = ['Date']
                  )
aqs_FULL2011

aqs_FULL2012 = pd.read_csv('../data/2012_EPA_AQI_FULL.csv',
                parse_dates = ['Date'],
                index_col = ['Date']
                  )
aqs_FULL2012

aqs_FULL2013 = pd.read_csv('../data/2013_EPA_AQI_FULL.csv',
                parse_dates = ['Date'],
                index_col = ['Date']
                  )
aqs_FULL2013

aqs_FULL2014 = pd.read_csv('../data/2014_EPA_AQI_FULL.csv',
                parse_dates = ['Date'],
                index_col = ['Date']
                  )
aqs_FULL2014

aqs_FULL2015 = pd.read_csv('../data/2015_EPA_AQI_FULL.csv',
                parse_dates = ['Date'],
                index_col = ['Date']
                  )
aqs_FULL2015

aqs_FULL2016 = pd.read_csv('../data/2016_EPA_AQI_FULL.csv',
                parse_dates = ['Date'],
                index_col = ['Date']
                  )
aqs_FULL2016

aqs_FULL2017 = pd.read_csv('../data/2017_EPA_AQI_FULL.csv',
                parse_dates = ['Date'],
                index_col = ['Date']
                  )
aqs_FULL2017

aqs_FULL2018 = pd.read_csv('../data/2018_EPA_AQI_FULL.csv',
                parse_dates = ['Date'],
                index_col = ['Date']
                  )
aqs_FULL2018

aqs_FULL2019 = pd.read_csv('../data/2019_EPA_AQI_FULL.csv',
                parse_dates = ['Date'],
                index_col = ['Date']
                  )
aqs_FULL2019

aqs_FULL2020 = pd.read_csv('../data/2020_EPA_AQI_FULL.csv',
                parse_dates = ['Date'],
                index_col = ['Date']
                  )
aqs_FULL2020

aqs_FULL2021 = pd.read_csv('../data/2021_EPA_AQI_FULL.csv',
                parse_dates = ['Date'],
                index_col = ['Date']
                  )
aqs_FULL2021

aqs_FULL2022 = pd.read_csv('../data/2022_EPA_AQI_FULL.csv',
                parse_dates = ['Date'],
                index_col = ['Date']
                  )
aqs_FULL2022

aqs_FULL2023 = pd.read_csv('../data/2023_EPA_AQI_FULL.csv',
                parse_dates = ['Date'],
                index_col = ['Date']
                  )
aqs_FULL2023

aqs_FULL2023_ComparisonData = pd.read_csv('../data/2023_EPA_AQI_ComparisonData.csv',
                parse_dates = ['Date'],
                index_col = ['Date']
                  )
aqs_FULL2023_ComparisonData
# Out:
#            Source   Site ID  POC  Daily Mean PM2.5 Concentration     UNITS  \
# Date
# 2023-01-01    AQS  60370016    3                             1.4  ug/m3 LC
# 2023-01-02    AQS  60370016    3                             4.0  ug/m3 LC
# 2023-01-03    AQS  60370016    3                             0.7  ug/m3 LC
# 2023-01-04    AQS  60370016    3                             0.5  ug/m3 LC
# 2023-01-05    AQS  60370016    3                             2.2  ug/m3 LC
# ...           ...       ...  ...                             ...       ...
# 2023-12-27    AQS  60371302    1                            25.4  ug/m3 LC
# 2023-12-28    AQS  60371302    1                            28.1  ug/m3 LC
# 2023-12-29    AQS  60371302    1                            31.2  ug/m3 LC
# 2023-12-30    AQS  60371302    1                             9.2  ug/m3 LC
# 2023-12-31    AQS  60371302    1                            28.5  ug/m3 LC
#
# ...

# %%
aqs_FULL2009.columns
# Out:
# Index(['Source', 'Site ID', 'POC', 'Daily Mean PM2.5 Concentration', 'UNITS',
#        'DAILY_AQI_VALUE', 'Site Name', 'DAILY_OBS_COUNT', 'PERCENT_COMPLETE',
#        'AQS_PARAMETER_CODE', 'AQS_PARAMETER_DESC', 'CBSA_CODE', 'CBSA_NAME',
#        'STATE_CODE', 'STATE', 'COUNTY_CODE', 'COUNTY', 'SITE_LATITUDE',
#        'SITE_LONGITUDE'],
#       dtype='object')

# %%
import numpy as np
import matplotlib.pyplot as plt 
import matplotlib.dates as mdates
import calendar
import matplotlib.patches as mpatches

def customize_tick_colors(ax):
    for tick in ax.get_yticklabels():
        try:
            tick_val = float(tick.get_text())
            if 0 <= tick_val <= 50:
                tick.set_color('mediumseagreen')
            elif 50 < tick_val <= 100:
                tick.set_color('goldenrod')
            elif 100 < tick_val <= 150:
                tick.set_color('darkorange')
            elif 150 < tick_val <= 200:
                tick.set_color('red')
            elif 200 < tick_val <= 300:
                tick.set_color('darkred')
        except ValueError:
            pass  # Skip non-numeric tick labels

fig,ax = plt.subplots(figsize=(10, 6))
ax.set_title('2009 Daily AQI Values', fontweight='bold', fontsize=16)
ax.set_xlabel('Date')
ax.set_ylabel('AQI Value')
aqs_FULL2009.loc[aqs_FULL2009['Site Name']=='Los Angeles-North Main Street'].plot(y='DAILY_AQI_VALUE', label='LA',ax=ax, alpha =0.7, color='c')
aqs_FULL2009.loc[aqs_FULL2009['Site Name']=='Glendora'].plot(y='DAILY_AQI_VALUE', label='Glendora',ax=ax, alpha =0.7, color='mediumblue')
aqs_FULL2009.loc[aqs_FULL2009['Site Name']=='Compton'].plot(y='DAILY_AQI_VALUE', label='Compton',ax=ax, alpha =1, color='navy')
aqs_FULL2023.loc[aqs_FULL2023['Site Name']=='Los Angeles-North Main Street'].plot(y='DAILY_AQI_VALUE', label='LA',ax=ax, alpha =0.7, color='mediumpurple')
aqs_FULL2023.loc[aqs_FULL2023['Site Name']=='Glendora'].plot(y='DAILY_AQI_VALUE', label='Glendora',ax=ax, alpha =0.7, color='darkviolet')
aqs_FULL2023.loc[aqs_FULL2023['Site Name']=='Compton'].plot(y='DAILY_AQI_VALUE', label='Compton',ax=ax, alpha =1, color='purple')
ax.xaxis.set_major_locator(mdates.MonthLocator())
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b'))
customize_tick_colors(ax)
ax.yaxis.set_tick_params(labelsize=12)
ax.xaxis.set_tick_params(labelsize=12)
legend_elements = [
    mpatches.Patch(color='mediumseagreen', label='Good'),
    mpatches.Patch(color='goldenrod', label='Moderate'),
    mpatches.Patch(color='darkorange', label='Unhealthy for Sensitive Groups'),
    mpatches.Patch(color='red', label='Unhealthy'),
    mpatches.Patch(color='darkred', label='Very Unhealthy')
]
ax.legend(handles=legend_elements, loc='upper center', bbox_to_anchor=(0.5, -0.18), ncol=5)
plt.show()

fig,ax = plt.subplots(figsize=(10, 6))
ax.set_title('2010 Daily AQI Values', fontweight='bold', fontsize=16)
ax.set_xlabel('Date')
ax.set_ylabel('AQI Value')
aqs_FULL2010.loc[aqs_FULL2010['Site Name']=='Los Angeles-North Main Street'].plot(y='DAILY_AQI_VALUE', label='LA',ax=ax, alpha =0.7, color='c')
aqs_FULL2010.loc[aqs_FULL2010['Site Name']=='Glendora'].plot(y='DAILY_AQI_VALUE', label='Glendora',ax=ax, alpha =0.7, color='mediumblue')
aqs_FULL2010.loc[aqs_FULL2010['Site Name']=='Compton'].plot(y='DAILY_AQI_VALUE', label='Compton',ax=ax, alpha =1, color='navy')
ax.xaxis.set_major_locator(mdates.MonthLocator())
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b'))
customize_tick_colors(ax)

fig,ax = plt.subplots(figsize=(10, 6))
ax.set_title('2011 Daily AQI Values', fontweight='bold', fontsize=16)
ax.set_xlabel('Date')
ax.set_ylabel('AQI Value')
aqs_FULL2011.loc[aqs_FULL2011['Site Name']=='Los Angeles-North Main Street'].plot(y='DAILY_AQI_VALUE', label='LA',ax=ax, alpha =0.7, color='c')
aqs_FULL2011.loc[aqs_FULL2011['Site Name']=='Glendora'].plot(y='DAILY_AQI_VALUE', label='Glendora',ax=ax, alpha =0.7, color='mediumblue')
aqs_FULL2011.loc[aqs_FULL2011['Site Name']=='Compton'].plot(y='DAILY_AQI_VALUE', label='Compton',ax=ax, alpha =1, color='navy')
ax.xaxis.set_major_locator(mdates.MonthLocator())
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b'))
customize_tick_colors(ax)

fig,ax = plt.subplots(figsize=(10, 6))
ax.set_title('2012 Daily AQI Values', fontweight='bold', fontsize=16)
ax.set_xlabel('Date')
ax.set_ylabel('AQI Value')
aqs_FULL2012.loc[aqs_FULL2012['Site Name']=='Los Angeles-North Main Street'].plot(y='DAILY_AQI_VALUE', label='LA',ax=ax, alpha =0.7, color='c')
aqs_FULL2012.loc[aqs_FULL2012['Site Name']=='Glendora'].plot(y='DAILY_AQI_VALUE', label='Glendora',ax=ax, alpha =0.7, color='mediumblue')
aqs_FULL2012.loc[aqs_FULL2012['Site Name']=='Compton'].plot(y='DAILY_AQI_VALUE', label='Compton',ax=ax, alpha =1, color='navy')
ax.xaxis.set_major_locator(mdates.MonthLocator())
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b'))
customize_tick_colors(ax)

fig,ax = plt.subplots(figsize=(10, 6))
ax.set_title('2013 Daily AQI Values', fontweight='bold', fontsize=16)
ax.set_xlabel('Date')
ax.set_ylabel('AQI Value')
aqs_FULL2013.loc[aqs_FULL2013['Site Name']=='Los Angeles-North Main Street'].plot(y='DAILY_AQI_VALUE', label='LA',ax=ax, alpha =0.7, color='c')
aqs_FULL2013.loc[aqs_FULL2013['Site Name']=='Glendora'].plot(y='DAILY_AQI_VALUE', label='Glendora',ax=ax, alpha =0.7, color='mediumblue')
aqs_FULL2013.loc[aqs_FULL2013['Site Name']=='Compton'].plot(y='DAILY_AQI_VALUE', label='Compton',ax=ax, alpha =1, color='navy')
ax.xaxis.set_major_locator(mdates.MonthLocator())
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b'))
customize_tick_colors(ax)

fig,ax = plt.subplots(figsize=(10, 6))
ax.set_title('2014 Daily AQI Values', fontweight='bold', fontsize=16)
ax.set_xlabel('Date')
ax.set_ylabel('AQI Value')
aqs_FULL2014.loc[aqs_FULL2014['Site Name']=='Los Angeles-North Main Street'].plot(y='DAILY_AQI_VALUE', label='LA',ax=ax, alpha =0.7, color='c')
aqs_FULL2014.loc[aqs_FULL2014['Site Name']=='Glendora'].plot(y='DAILY_AQI_VALUE', label='Glendora',ax=ax, alpha =0.7, color='mediumblue')
aqs_FULL2014.loc[aqs_FULL2014['Site Name']=='Compton'].plot(y='DAILY_AQI_VALUE', label='Compton',ax=ax, alpha =1, color='navy')
ax.xaxis.set_major_locator(mdates.MonthLocator())
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b'))
customize_tick_colors(ax)

fig,ax = plt.subplots(figsize=(10, 6))
ax.set_title('2015 Daily AQI Values', fontweight='bold', fontsize=16)
ax.set_xlabel('Date')
ax.set_ylabel('AQI Value')
aqs_FULL2015.loc[aqs_FULL2015['Site Name']=='Los Angeles-North Main Street'].plot(y='DAILY_AQI_VALUE', label='LA',ax=ax, alpha =0.7, color='c')
aqs_FULL2015.loc[aqs_FULL2015['Site Name']=='Glendora'].plot(y='DAILY_AQI_VALUE', label='Glendora',ax=ax, alpha =0.7, color='mediumblue')
aqs_FULL2015.loc[aqs_FULL2015['Site Name']=='Compton'].plot(y='DAILY_AQI_VALUE', label='Compton',ax=ax, alpha =1, color='navy')
ax.xaxis.set_major_locator(mdates.MonthLocator())
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b'))
customize_tick_colors(ax)

fig,ax = plt.subplots(figsize=(10, 6))
ax.set_title('2016 Daily AQI Values', fontweight='bold', fontsize=16)
ax.set_xlabel('Date')
ax.set_ylabel('AQI Value')
aqs_FULL2016.loc[aqs_FULL2016['Site Name']=='Los Angeles-North Main Street'].plot(y='DAILY_AQI_VALUE', label='LA',ax=ax, alpha =0.7, color='c')
aqs_FULL2016.loc[aqs_FULL2016['Site Name']=='Glendora'].plot(y='DAILY_AQI_VALUE', label='Glendora',ax=ax, alpha =0.7, color='mediumblue')
aqs_FULL2016.loc[aqs_FULL2016['Site Name']=='Compton'].plot(y='DAILY_AQI_VALUE', label='Compton',ax=ax, alpha =1, color='navy')
ax.xaxis.set_major_locator(mdates.MonthLocator())
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b'))
customize_tick_colors(ax)

fig,ax = plt.subplots(figsize=(10, 6))
ax.set_title('2017 Daily AQI Values', fontweight='bold', fontsize=16)
ax.set_xlabel('Date')
ax.set_ylabel('AQI Value')
aqs_FULL2017.loc[aqs_FULL2017['Site Name']=='Los Angeles-North Main Street'].plot(y='DAILY_AQI_VALUE', label='LA',ax=ax, alpha =0.7, color='c')
aqs_FULL2017.loc[aqs_FULL2017['Site Name']=='Glendora'].plot(y='DAILY_AQI_VALUE', label='Glendora',ax=ax, alpha =0.7, color='mediumblue')
aqs_FULL2017.loc[aqs_FULL2017['Site Name']=='Compton'].plot(y='DAILY_AQI_VALUE', label='Compton',ax=ax, alpha =1, color='navy')
ax.xaxis.set_major_locator(mdates.MonthLocator())
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b'))
customize_tick_colors(ax)

fig,ax = plt.subplots(figsize=(10, 6))
ax.set_title('2018 Daily AQI Values', fontweight='bold', fontsize=16)
ax.set_xlabel('Date')
ax.set_ylabel('AQI Value')
aqs_FULL2018.loc[aqs_FULL2018['Site Name']=='Los Angeles-North Main Street'].plot(y='DAILY_AQI_VALUE', label='LA',ax=ax, alpha =0.7, color='c')
aqs_FULL2018.loc[aqs_FULL2018['Site Name']=='Glendora'].plot(y='DAILY_AQI_VALUE', label='Glendora',ax=ax, alpha =0.7, color='mediumblue')
aqs_FULL2018.loc[aqs_FULL2018['Site Name']=='Compton'].plot(y='DAILY_AQI_VALUE', label='Compton',ax=ax, alpha =1, color='navy')
ax.xaxis.set_major_locator(mdates.MonthLocator())
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b'))
customize_tick_colors(ax)

fig,ax = plt.subplots(figsize=(10, 6))
ax.set_title('2019 Daily AQI Values', fontweight='bold', fontsize=16)
ax.set_xlabel('Date')
ax.set_ylabel('AQI Value')
aqs_FULL2019.loc[aqs_FULL2019['Site Name']=='Los Angeles-North Main Street'].plot(y='DAILY_AQI_VALUE', label='LA',ax=ax, alpha =0.7, color='c')
aqs_FULL2019.loc[aqs_FULL2019['Site Name']=='Glendora'].plot(y='DAILY_AQI_VALUE', label='Glendora',ax=ax, alpha =0.7, color='mediumblue')
aqs_FULL2019.loc[aqs_FULL2019['Site Name']=='Compton'].plot(y='DAILY_AQI_VALUE', label='Compton',ax=ax, alpha =1, color='navy')
ax.xaxis.set_major_locator(mdates.MonthLocator())
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b'))
customize_tick_colors(ax)

fig,ax = plt.subplots(figsize=(10, 6))
ax.set_title('2020 Daily AQI Values', fontweight='bold', fontsize=16)
ax.set_xlabel('Date')
ax.set_ylabel('AQI Value')
aqs_FULL2020.loc[aqs_FULL2020['Site Name']=='Los Angeles-North Main Street'].plot(y='DAILY_AQI_VALUE', label='LA',ax=ax, alpha =0.7, color='c')
aqs_FULL2020.loc[aqs_FULL2020['Site Name']=='Glendora'].plot(y='DAILY_AQI_VALUE', label='Glendora',ax=ax, alpha =0.7, color='mediumblue')
aqs_FULL2020.loc[aqs_FULL2020['Site Name']=='Compton'].plot(y='DAILY_AQI_VALUE', label='Compton',ax=ax, alpha =1, color='navy')
ax.xaxis.set_major_locator(mdates.MonthLocator())
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b'))
customize_tick_colors(ax)

fig,ax = plt.subplots(figsize=(10, 6))
ax.set_title('2021 Daily AQI Values', fontweight='bold', fontsize=16)
ax.set_xlabel('Date')
ax.set_ylabel('AQI Value')
aqs_FULL2021.loc[aqs_FULL2021['Site Name']=='Los Angeles-North Main Street'].plot(y='DAILY_AQI_VALUE', label='LA',ax=ax, alpha =0.7, color='c')
aqs_FULL2021.loc[aqs_FULL2021['Site Name']=='Glendora'].plot(y='DAILY_AQI_VALUE', label='Glendora',ax=ax, alpha =0.7, color='mediumblue')
aqs_FULL2021.loc[aqs_FULL2021['Site Name']=='Compton'].plot(y='DAILY_AQI_VALUE', label='Compton',ax=ax, alpha =1, color='navy')
ax.xaxis.set_major_locator(mdates.MonthLocator())
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b'))
customize_tick_colors(ax)

fig,ax = plt.subplots(figsize=(10, 6))
ax.set_title('2022 Daily AQI Values', fontweight='bold', fontsize=16)
ax.set_xlabel('Date')
ax.set_ylabel('AQI Value')
aqs_FULL2022.loc[aqs_FULL2022['Site Name']=='Los Angeles-North Main Street'].plot(y='DAILY_AQI_VALUE', label='LA',ax=ax, alpha =0.7, color='c')
aqs_FULL2022.loc[aqs_FULL2022['Site Name']=='Glendora'].plot(y='DAILY_AQI_VALUE', label='Glendora',ax=ax, alpha =0.7, color='mediumblue')
aqs_FULL2022.loc[aqs_FULL2022['Site Name']=='Compton'].plot(y='DAILY_AQI_VALUE', label='Compton',ax=ax, alpha =1, color='navy')
ax.xaxis.set_major_locator(mdates.MonthLocator())
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b'))
customize_tick_colors(ax)

fig,ax = plt.subplots(figsize=(10, 6))
ax.set_title('2023 Daily AQI Values', fontweight='bold', fontsize=16)
ax.set_xlabel('Date')
ax.set_ylabel('AQI Value')
aqs_FULL2023.loc[aqs_FULL2023['Site Name']=='Los Angeles-North Main Street'].plot(y='DAILY_AQI_VALUE', label='LA',ax=ax, alpha =0.7, color='c')
aqs_FULL2023.loc[aqs_FULL2023['Site Name']=='Glendora'].plot(y='DAILY_AQI_VALUE', label='Glendora',ax=ax, alpha =0.7, color='mediumblue')
aqs_FULL2023.loc[aqs_FULL2023['Site Name']=='Compton'].plot(y='DAILY_AQI_VALUE', label='Compton',ax=ax, alpha =1, color='navy')
ax.xaxis.set_major_locator(mdates.MonthLocator())
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b'))
customize_tick_colors(ax)

# %%
fig,ax = plt.subplots()
ax.set_title('2009 Daily AQI Values', fontweight='bold')
aqs_FULL2009.loc[aqs_FULL2009['Site Name']=='Compton'].plot(kind='hist', y='DAILY_AQI_VALUE', label='Compton',ax=ax, alpha =0.5, density = True, color='navy')
aqs_FULL2009.loc[aqs_FULL2009['Site Name']=='Glendora'].plot(kind='hist', y='DAILY_AQI_VALUE', label='Gelndora',ax=ax, alpha =0.7, density = True, color='mediumblue')
aqs_FULL2009.loc[aqs_FULL2009['Site Name']=='Los Angeles-North Main Street'].plot(kind='hist', y='DAILY_AQI_VALUE', label='LA ',ax=ax, alpha =0.5, density = True, color='c')
ax.yaxis.set_tick_params(labelsize=12)
ax.xaxis.set_tick_params(labelsize=12)
ax.legend(handles=legend_elements2,  loc='right')


fig,ax = plt.subplots()
ax.set_title('2010 Daily AQI Values', fontweight='bold')
aqs_FULL2010.loc[aqs_FULL2010['Site Name']=='Compton'].plot(kind='hist', y='DAILY_AQI_VALUE', label='Compton',ax=ax, alpha =0.5, density = True, color='navy')
aqs_FULL2010.loc[aqs_FULL2010['Site Name']=='Glendora'].plot(kind='hist', y='DAILY_AQI_VALUE', label='Gelndora',ax=ax, alpha =0.7, density = True, color='mediumblue')
aqs_FULL2010.loc[aqs_FULL2010['Site Name']=='Los Angeles-North Main Street'].plot(kind='hist', y='DAILY_AQI_VALUE', label='LA ',ax=ax, alpha =0.5, density = True, color='c')

fig,ax = plt.subplots()
ax.set_title('2011 Daily AQI Values', fontweight='bold')
aqs_FULL2011.loc[aqs_FULL2011['Site Name']=='Compton'].plot(kind='hist', y='DAILY_AQI_VALUE', label='Compton',ax=ax, alpha =0.5, density = True, color='navy')
aqs_FULL2011.loc[aqs_FULL2011['Site Name']=='Glendora'].plot(kind='hist', y='DAILY_AQI_VALUE', label='Gelndora',ax=ax, alpha =0.7, density = True, color='mediumblue')
aqs_FULL2011.loc[aqs_FULL2011['Site Name']=='Los Angeles-North Main Street'].plot(kind='hist', y='DAILY_AQI_VALUE', label='LA ',ax=ax, alpha =0.5, density = True, color='c')

fig,ax = plt.subplots()
ax.set_title('2012 Daily AQI Values', fontweight='bold')
aqs_FULL2012.loc[aqs_FULL2012['Site Name']=='Compton'].plot(kind='hist', y='DAILY_AQI_VALUE', label='Compton',ax=ax, alpha =0.5, density = True, color='navy')
aqs_FULL2012.loc[aqs_FULL2012['Site Name']=='Glendora'].plot(kind='hist', y='DAILY_AQI_VALUE', label='Gelndora',ax=ax, alpha =0.7, density = True, color='mediumblue')
aqs_FULL2012.loc[aqs_FULL2012['Site Name']=='Los Angeles-North Main Street'].plot(kind='hist', y='DAILY_AQI_VALUE', label='LA ',ax=ax, alpha =0.5, density = True, color='c')

fig,ax = plt.subplots()
ax.set_title('2013 Daily AQI Values', fontweight='bold')
aqs_FULL2013.loc[aqs_FULL2013['Site Name']=='Compton'].plot(kind='hist', y='DAILY_AQI_VALUE', label='Compton',ax=ax, alpha =0.5, density = True, color='navy')
aqs_FULL2013.loc[aqs_FULL2013['Site Name']=='Glendora'].plot(kind='hist', y='DAILY_AQI_VALUE', label='Gelndora',ax=ax, alpha =0.7, density = True, color='mediumblue')
aqs_FULL2013.loc[aqs_FULL2013['Site Name']=='Los Angeles-North Main Street'].plot(kind='hist', y='DAILY_AQI_VALUE', label='LA ',ax=ax, alpha =0.5, density = True, color='c')

fig,ax = plt.subplots()
ax.set_title('2014 Daily AQI Values', fontweight='bold')
aqs_FULL2014.loc[aqs_FULL2014['Site Name']=='Compton'].plot(kind='hist', y='DAILY_AQI_VALUE', label='Compton',ax=ax, alpha =0.5, density = True, color='navy')
aqs_FULL2014.loc[aqs_FULL2014['Site Name']=='Glendora'].plot(kind='hist', y='DAILY_AQI_VALUE', label='Gelndora',ax=ax, alpha =0.7, density = True, color='mediumblue')
aqs_FULL2014.loc[aqs_FULL2014['Site Name']=='Los Angeles-North Main Street'].plot(kind='hist', y='DAILY_AQI_VALUE', label='LA ',ax=ax, alpha =0.5, density = True, color='c')

fig,ax = plt.subplots()
ax.set_title('2015 Daily AQI Values', fontweight='bold')
aqs_FULL2015.loc[aqs_FULL2015['Site Name']=='Compton'].plot(kind='hist', y='DAILY_AQI_VALUE', label='Compton',ax=ax, alpha =0.5, density = True, color='navy')
aqs_FULL2015.loc[aqs_FULL2015['Site Name']=='Glendora'].plot(kind='hist', y='DAILY_AQI_VALUE', label='Gelndora',ax=ax, alpha =0.7, density = True, color='mediumblue')
aqs_FULL2015.loc[aqs_FULL2015['Site Name']=='Los Angeles-North Main Street'].plot(kind='hist', y='DAILY_AQI_VALUE', label='LA ',ax=ax, alpha =0.5, density = True, color='c')

fig,ax = plt.subplots()
ax.set_title('2016 Daily AQI Values', fontweight='bold')
aqs_FULL2016.loc[aqs_FULL2016['Site Name']=='Compton'].plot(kind='hist', y='DAILY_AQI_VALUE', label='Compton',ax=ax, alpha =0.5, density = True, color='navy')
aqs_FULL2016.loc[aqs_FULL2016['Site Name']=='Glendora'].plot(kind='hist', y='DAILY_AQI_VALUE', label='Gelndora',ax=ax, alpha =0.7, density = True, color='mediumblue')
aqs_FULL2016.loc[aqs_FULL2016['Site Name']=='Los Angeles-North Main Street'].plot(kind='hist', y='DAILY_AQI_VALUE', label='LA ',ax=ax, alpha =0.5, density = True, color='c')

fig,ax = plt.subplots()
ax.set_title('2017 Daily AQI Values', fontweight='bold')
aqs_FULL2017.loc[aqs_FULL2017['Site Name']=='Compton'].plot(kind='hist', y='DAILY_AQI_VALUE', label='Compton',ax=ax, alpha =0.5, density = True, color='navy')
aqs_FULL2017.loc[aqs_FULL2017['Site Name']=='Glendora'].plot(kind='hist', y='DAILY_AQI_VALUE', label='Gelndora',ax=ax, alpha =0.7, density = True, color='mediumblue')
aqs_FULL2017.loc[aqs_FULL2017['Site Name']=='Los Angeles-North Main Street'].plot(kind='hist', y='DAILY_AQI_VALUE', label='LA ',ax=ax, alpha =0.5, density = True, color='c')

fig,ax = plt.subplots()
ax.set_title('2018 Daily AQI Values', fontweight='bold')
aqs_FULL2018.loc[aqs_FULL2018['Site Name']=='Compton'].plot(kind='hist', y='DAILY_AQI_VALUE', label='Compton',ax=ax, alpha =0.5, density = True, color='navy')
aqs_FULL2018.loc[aqs_FULL2018['Site Name']=='Glendora'].plot(kind='hist', y='DAILY_AQI_VALUE', label='Gelndora',ax=ax, alpha =0.7, density = True, color='mediumblue')
aqs_FULL2018.loc[aqs_FULL2018['Site Name']=='Los Angeles-North Main Street'].plot(kind='hist', y='DAILY_AQI_VALUE', label='LA ',ax=ax, alpha =0.5, density = True, color='c')

fig,ax = plt.subplots()
ax.set_title('2019 Daily AQI Values', fontweight='bold')
aqs_FULL2019.loc[aqs_FULL2019['Site Name']=='Compton'].plot(kind='hist', y='DAILY_AQI_VALUE', label='Compton',ax=ax, alpha =0.5, density = True, color='navy')
aqs_FULL2019.loc[aqs_FULL2019['Site Name']=='Glendora'].plot(kind='hist', y='DAILY_AQI_VALUE', label='Gelndora',ax=ax, alpha =0.7, density = True, color='mediumblue')
aqs_FULL2019.loc[aqs_FULL2019['Site Name']=='Los Angeles-North Main Street'].plot(kind='hist', y='DAILY_AQI_VALUE', label='LA ',ax=ax, alpha =0.5, density = True, color='c')

fig,ax = plt.subplots()
ax.set_title('2020 Daily AQI Values', fontweight='bold')
aqs_FULL2020.loc[aqs_FULL2020['Site Name']=='Compton'].plot(kind='hist', y='DAILY_AQI_VALUE', label='Compton',ax=ax, alpha =0.5, density = True, color='navy')
aqs_FULL2020.loc[aqs_FULL2020['Site Name']=='Glendora'].plot(kind='hist', y='DAILY_AQI_VALUE', label='Gelndora',ax=ax, alpha =0.7, density = True, color='mediumblue')
aqs_FULL2020.loc[aqs_FULL2020['Site Name']=='Los Angeles-North Main Street'].plot(kind='hist', y='DAILY_AQI_VALUE', label='LA ',ax=ax, alpha =0.5, density = True, color='c')

fig,ax = plt.subplots()
ax.set_title('2021 Daily AQI Values', fontweight='bold')
aqs_FULL2021.loc[aqs_FULL2021['Site Name']=='Compton'].plot(kind='hist', y='DAILY_AQI_VALUE', label='Compton',ax=ax, alpha =0.5, density = True, color='navy')
aqs_FULL2021.loc[aqs_FULL2021['Site Name']=='Glendora'].plot(kind='hist', y='DAILY_AQI_VALUE', label='Gelndora',ax=ax, alpha =0.7, density = True, color='mediumblue')
aqs_FULL2021.loc[aqs_FULL2021['Site Name']=='Los Angeles-North Main Street'].plot(kind='hist', y='DAILY_AQI_VALUE', label='LA ',ax=ax, alpha =0.5, density = True, color='c')

fig,ax = plt.subplots()
ax.set_title('2022 Daily AQI Values', fontweight='bold')
aqs_FULL2022.loc[aqs_FULL2022['Site Name']=='Compton'].plot(kind='hist', y='DAILY_AQI_VALUE', label='Compton',ax=ax, alpha =0.5, density = True, color='navy')
aqs_FULL2022.loc[aqs_FULL2022['Site Name']=='Glendora'].plot(kind='hist', y='DAILY_AQI_VALUE', label='Gelndora',ax=ax, alpha =0.7, density = True, color='mediumblue')
aqs_FULL2022.loc[aqs_FULL2022['Site Name']=='Los Angeles-North Main Street'].plot(kind='hist', y='DAILY_AQI_VALUE', label='LA ',ax=ax, alpha =0.5, density = True, color='c')

fig,ax = plt.subplots()
ax.set_title('2023 Daily AQI Values', fontweight='bold')
aqs_FULL2023.loc[aqs_FULL2023['Site Name']=='Compton'].plot(kind='hist', y='DAILY_AQI_VALUE', label='Compton',ax=ax, alpha =0.5, density = True, color='navy')
aqs_FULL2023.loc[aqs_FULL2023['Site Name']=='Glendora'].plot(kind='hist', y='DAILY_AQI_VALUE', label='Gelndora',ax=ax, alpha =0.7, density = True, color='mediumblue')
aqs_FULL2023.loc[aqs_FULL2023['Site Name']=='Los Angeles-North Main Street'].plot(kind='hist', y='DAILY_AQI_VALUE', label='LA ',ax=ax, alpha =0.5, density = True, color='c')
# Out:
# <Axes: title={'center': '2023 Daily AQI Values'}, ylabel='Frequency'>

# %%
fig,ax = plt.subplots()
ax.set_title('2009 vs 2023 Daily AQI Values: Compton', fontweight='bold')
aqs_FULL2009.loc[aqs_FULL2009['Site Name']=='Compton'].plot(kind='hist', y='DAILY_AQI_VALUE', label='Compton-2009',ax=ax, alpha =0.5, density = True, color='mediumblue')
aqs_FULL2023.loc[aqs_FULL2023['Site Name']=='Compton'].plot(kind='hist', y='DAILY_AQI_VALUE', label='Compton-2023',ax=ax, alpha =0.5, density = True, color='c')

fig,ax = plt.subplots()
ax.set_title('2009 vs 2023 Daily AQI Values: Glendora', fontweight='bold')
aqs_FULL2009.loc[aqs_FULL2009['Site Name']=='Glendora'].plot(kind='hist', y='DAILY_AQI_VALUE', label='Glendora-2009',ax=ax, alpha =0.5, density = True, color='mediumblue')
aqs_FULL2023.loc[aqs_FULL2023['Site Name']=='Glendora'].plot(kind='hist', y='DAILY_AQI_VALUE', label='Glendora-2023',ax=ax, alpha =0.5, density = True, color='c')

fig,ax = plt.subplots()
ax.set_title('2009 vs 2023 Daily AQI Values: Los Angeles', fontweight='bold')
aqs_FULL2009.loc[aqs_FULL2009['Site Name']=='Los Angeles-North Main Street'].plot(kind='hist', y='DAILY_AQI_VALUE', label='LA-N Main Street-2009',ax=ax, alpha =0.5, density = True, color='mediumblue')
aqs_FULL2023.loc[aqs_FULL2023['Site Name']=='Los Angeles-North Main Street'].plot(kind='hist', y='DAILY_AQI_VALUE', label='LA-N Main Street-2023',ax=ax, alpha =0.5, density = True, color='c')
# Out:
# <Axes: title={'center': '2009 vs 2023 Daily AQI Values: Los Angeles'}, ylabel='Frequency'>

# %%
fig,ax = plt.subplots()
aqs_FULL2009.loc[aqs_FULL2009['Site Name']=='Compton'].plot(kind='hist', y='Daily Mean PM2.5 Concentration', label='Compton-2009',ax=ax, alpha =0.5, density = True)
aqs_FULL2023.loc[aqs_FULL2023['Site Name']=='Compton'].plot(kind='hist', y='Daily Mean PM2.5 Concentration', label='Compton-2023',ax=ax, alpha =0.5, density = True)

fig,ax = plt.subplots()
aqs_FULL2009.loc[aqs_FULL2009['Site Name']=='Glendora'].plot(kind='hist', y='Daily Mean PM2.5 Concentration', label='Glendora-2009',ax=ax, alpha =0.5, density = True)
aqs_FULL2023.loc[aqs_FULL2023['Site Name']=='Glendora'].plot(kind='hist', y='Daily Mean PM2.5 Concentration', label='Glendora-2023',ax=ax, alpha =0.5, density = True)

fig,ax = plt.subplots()
aqs_FULL2009.loc[aqs_FULL2009['Site Name']=='Los Angeles-North Main Street'].plot(kind='hist', y='Daily Mean PM2.5 Concentration', label='LA-N Main Street-2009',ax=ax, alpha =0.5, density = True)
aqs_FULL2023.loc[aqs_FULL2023['Site Name']=='Los Angeles-North Main Street'].plot(kind='hist', y='Daily Mean PM2.5 Concentration', label='LA-N Main Street-2023',ax=ax, alpha =0.5, density = True)
# Out:
# <Axes: ylabel='Frequency'>

# %%
aqs_FULL2009.columns
# Out:
# Index(['Source', 'Site ID', 'POC', 'Daily Mean PM2.5 Concentration', 'UNITS',
#        'DAILY_AQI_VALUE', 'Site Name', 'DAILY_OBS_COUNT', 'PERCENT_COMPLETE',
#        'AQS_PARAMETER_CODE', 'AQS_PARAMETER_DESC', 'CBSA_CODE', 'CBSA_NAME',
#        'STATE_CODE', 'STATE', 'COUNTY_CODE', 'COUNTY', 'SITE_LATITUDE',
#        'SITE_LONGITUDE'],
#       dtype='object')

# %%
aqs_FULL2023.columns
# Out:
# Index(['Source', 'Site ID', 'POC', 'Daily Mean PM2.5 Concentration', 'UNITS',
#        'DAILY_AQI_VALUE', 'Site Name', 'DAILY_OBS_COUNT', 'PERCENT_COMPLETE',
#        'AQS_PARAMETER_CODE', 'AQS_PARAMETER_DESC', 'CBSA_CODE', 'CBSA_NAME',
#        'STATE_CODE', 'STATE', 'COUNTY_CODE', 'COUNTY', 'SITE_LATITUDE',
#        'SITE_LONGITUDE'],
#       dtype='object')

# %%
#compare three towns for a couple of the years
#    - check for consistancy
#All of the years for one location, x3 locations
#   - split it

# %%
statistics_Compton=pd.DataFrame()
statistics_Compton['2009']=aqs_FULL2009.loc[aqs_FULL2009['Site Name']=='Compton']['DAILY_AQI_VALUE'].describe()
statistics_Compton['2010']=aqs_FULL2010.loc[aqs_FULL2010['Site Name']=='Compton']['DAILY_AQI_VALUE'].describe()
statistics_Compton['2011']=aqs_FULL2011.loc[aqs_FULL2011['Site Name']=='Compton']['DAILY_AQI_VALUE'].describe()
statistics_Compton['2012']=aqs_FULL2012.loc[aqs_FULL2012['Site Name']=='Compton']['DAILY_AQI_VALUE'].describe()
statistics_Compton['2013']=aqs_FULL2013.loc[aqs_FULL2013['Site Name']=='Compton']['DAILY_AQI_VALUE'].describe()
statistics_Compton['2014']=aqs_FULL2014.loc[aqs_FULL2014['Site Name']=='Compton']['DAILY_AQI_VALUE'].describe()
statistics_Compton['2015']=aqs_FULL2015.loc[aqs_FULL2015['Site Name']=='Compton']['DAILY_AQI_VALUE'].describe()
statistics_Compton['2016']=aqs_FULL2016.loc[aqs_FULL2016['Site Name']=='Compton']['DAILY_AQI_VALUE'].describe()
statistics_Compton['2017']=aqs_FULL2017.loc[aqs_FULL2017['Site Name']=='Compton']['DAILY_AQI_VALUE'].describe()
statistics_Compton['2018']=aqs_FULL2018.loc[aqs_FULL2018['Site Name']=='Compton']['DAILY_AQI_VALUE'].describe()
statistics_Compton['2019']=aqs_FULL2019.loc[aqs_FULL2019['Site Name']=='Compton']['DAILY_AQI_VALUE'].describe()
statistics_Compton['2020']=aqs_FULL2020.loc[aqs_FULL2020['Site Name']=='Compton']['DAILY_AQI_VALUE'].describe()
statistics_Compton['2021']=aqs_FULL2021.loc[aqs_FULL2021['Site Name']=='Compton']['DAILY_AQI_VALUE'].describe()
statistics_Compton['2022']=aqs_FULL2022.loc[aqs_FULL2022['Site Name']=='Compton']['DAILY_AQI_VALUE'].describe()
statistics_Compton['2023']=aqs_FULL2023.loc[aqs_FULL2023['Site Name']=='Compton']['DAILY_AQI_VALUE'].describe()

# %%
statistics_Glendora=pd.DataFrame()
statistics_Glendora['2009']=aqs_FULL2009.loc[aqs_FULL2009['Site Name']=='Glendora']['DAILY_AQI_VALUE'].describe()
statistics_Glendora['2010']=aqs_FULL2010.loc[aqs_FULL2010['Site Name']=='Glendora']['DAILY_AQI_VALUE'].describe()
statistics_Glendora['2011']=aqs_FULL2011.loc[aqs_FULL2011['Site Name']=='Glendora']['DAILY_AQI_VALUE'].describe()
statistics_Glendora['2012']=aqs_FULL2012.loc[aqs_FULL2012['Site Name']=='Glendora']['DAILY_AQI_VALUE'].describe()
statistics_Glendora['2013']=aqs_FULL2013.loc[aqs_FULL2013['Site Name']=='Glendora']['DAILY_AQI_VALUE'].describe()
statistics_Glendora['2014']=aqs_FULL2014.loc[aqs_FULL2014['Site Name']=='Glendora']['DAILY_AQI_VALUE'].describe()
statistics_Glendora['2015']=aqs_FULL2015.loc[aqs_FULL2015['Site Name']=='Glendora']['DAILY_AQI_VALUE'].describe()
statistics_Glendora['2016']=aqs_FULL2016.loc[aqs_FULL2016['Site Name']=='Glendora']['DAILY_AQI_VALUE'].describe()
statistics_Glendora['2017']=aqs_FULL2017.loc[aqs_FULL2017['Site Name']=='Glendora']['DAILY_AQI_VALUE'].describe()
statistics_Glendora['2018']=aqs_FULL2018.loc[aqs_FULL2018['Site Name']=='Glendora']['DAILY_AQI_VALUE'].describe()
statistics_Glendora['2019']=aqs_FULL2019.loc[aqs_FULL2019['Site Name']=='Glendora']['DAILY_AQI_VALUE'].describe()
statistics_Glendora['2020']=aqs_FULL2020.loc[aqs_FULL2020['Site Name']=='Glendora']['DAILY_AQI_VALUE'].describe()
statistics_Glendora['2021']=aqs_FULL2021.loc[aqs_FULL2021['Site Name']=='Glendora']['DAILY_AQI_VALUE'].describe()
statistics_Glendora['2022']=aqs_FULL2022.loc[aqs_FULL2022['Site Name']=='Glendora']['DAILY_AQI_VALUE'].describe()
statistics_Glendora['2023']=aqs_FULL2023.loc[aqs_FULL2023['Site Name']=='Glendora']['DAILY_AQI_VALUE'].describe()

# %%
statistics_LA=pd.DataFrame()
statistics_LA['2009']=aqs_FULL2009.loc[aqs_FULL2009['Site Name']=='Los Angeles-North Main Street']['DAILY_AQI_VALUE'].describe()
statistics_LA['2010']=aqs_FULL2010.loc[aqs_FULL2010['Site Name']=='Los Angeles-North Main Street']['DAILY_AQI_VALUE'].describe()
statistics_LA['2011']=aqs_FULL2011.loc[aqs_FULL2011['Site Name']=='Los Angeles-North Main Street']['DAILY_AQI_VALUE'].describe()
statistics_LA['2012']=aqs_FULL2012.loc[aqs_FULL2012['Site Name']=='Los Angeles-North Main Street']['DAILY_AQI_VALUE'].describe()
statistics_LA['2013']=aqs_FULL2013.loc[aqs_FULL2013['Site Name']=='Los Angeles-North Main Street']['DAILY_AQI_VALUE'].describe()
statistics_LA['2014']=aqs_FULL2014.loc[aqs_FULL2014['Site Name']=='Los Angeles-North Main Street']['DAILY_AQI_VALUE'].describe()
statistics_LA['2015']=aqs_FULL2015.loc[aqs_FULL2015['Site Name']=='Los Angeles-North Main Street']['DAILY_AQI_VALUE'].describe()
statistics_LA['2016']=aqs_FULL2016.loc[aqs_FULL2016['Site Name']=='Los Angeles-North Main Street']['DAILY_AQI_VALUE'].describe()
statistics_LA['2017']=aqs_FULL2017.loc[aqs_FULL2017['Site Name']=='Los Angeles-North Main Street']['DAILY_AQI_VALUE'].describe()
statistics_LA['2018']=aqs_FULL2018.loc[aqs_FULL2018['Site Name']=='Los Angeles-North Main Street']['DAILY_AQI_VALUE'].describe()
statistics_LA['2019']=aqs_FULL2019.loc[aqs_FULL2019['Site Name']=='Los Angeles-North Main Street']['DAILY_AQI_VALUE'].describe()
statistics_LA['2020']=aqs_FULL2020.loc[aqs_FULL2020['Site Name']=='Los Angeles-North Main Street']['DAILY_AQI_VALUE'].describe()
statistics_LA['2021']=aqs_FULL2021.loc[aqs_FULL2021['Site Name']=='Los Angeles-North Main Street']['DAILY_AQI_VALUE'].describe()
statistics_LA['2022']=aqs_FULL2022.loc[aqs_FULL2022['Site Name']=='Los Angeles-North Main Street']['DAILY_AQI_VALUE'].describe()
statistics_LA['2023']=aqs_FULL2023.loc[aqs_FULL2023['Site Name']=='Los Angeles-North Main Street']['DAILY_AQI_VALUE'].describe()

# %%
statistics_Compton # add the other years 
statistics_Glendora
statistics_LA
# Out:
#               2009        2010        2011        2012        2013  \
# count  1016.000000  894.000000  814.000000  955.000000  973.000000
# mean     57.983268   52.270694   53.379607   55.023037   54.101747
# std      21.242877   19.110760   21.067796   21.800109   17.653353
# min      15.000000    0.000000   10.000000    0.000000    3.000000
# 25%      45.000000   39.000000   39.000000   41.000000   42.000000
# 50%      56.000000   53.000000   52.500000   54.000000   53.000000
# 75%      68.000000   63.000000   63.000000   67.000000   64.000000
# max     158.000000  138.000000  158.000000  163.000000  149.000000
#
#              2014        2015        2016        2017        2018        2019  \
# count  656.000000  797.000000  872.000000  896.000000  888.000000  893.000000
# mean    60.137195   52.474279   49.793578   50.641741   51.629505   45.017917
# std     20.875628   22.059841   18.644750   19.264869   20.614601   16.247584
# ...

# %%
statistics_Compton.T
statistics_Glendora.T
statistics_LA.T
# Out:
#        count       mean        std   min   25%   50%   75%    max
# 2009  1016.0  57.983268  21.242877  15.0  45.0  56.0  68.0  158.0
# 2010   894.0  52.270694  19.110760   0.0  39.0  53.0  63.0  138.0
# 2011   814.0  53.379607  21.067796  10.0  39.0  52.5  63.0  158.0
# 2012   955.0  55.023037  21.800109   0.0  41.0  54.0  67.0  163.0
# 2013   973.0  54.101747  17.653353   3.0  42.0  53.0  64.0  149.0
# 2014   656.0  60.137195  20.875628   2.0  48.0  59.0  71.0  156.0
# 2015   797.0  52.474279  22.059841   5.0  38.0  52.0  62.0  159.0
# 2016   872.0  49.793578  18.644750   0.0  38.0  49.0  59.0  135.0
# 2017   896.0  50.641741  19.264869   9.0  37.0  51.5  60.0  154.0
# 2018   888.0  51.629505  20.614601  10.0  37.0  51.0  62.0  156.0
# 2019   893.0  45.017917  16.247584   8.0  33.0  45.0  56.0  121.0
# 2020   867.0  50.955017  24.225157   5.0  35.0  51.0  62.0  225.0
# 2021   896.0  50.714286  20.922599   7.0  38.0  50.0  59.0  155.0
# ...

# %%
fig,ax = plt.subplots()
statistics_Compton.T.plot(y='mean',ax=ax, label='Compton', color='navy')
statistics_Glendora.T.plot(y='mean',ax=ax,label='Glendora', color='mediumblue')
statistics_LA.T.plot(y='mean',ax=ax,label='LA', color='c')
ax.set_title('Annual Mean AQI', fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Annual Mean AQI')
